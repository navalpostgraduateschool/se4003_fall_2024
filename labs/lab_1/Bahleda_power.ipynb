# %% [markdown]
# ## Lab 02_Bahleda: *_Microgrid Resilience Analysis_*
#
#
# This lab investigates the resilience of microgrids using power data.
#
# **Objectives**:
# - Learn about Python and Jupyter Lab
# - Use Pandas to manipulate data
# - Analyze microgrid power data

# %%
from power_loads import *
import pandas

df_14=pandas.read_csv('data/constant_14days.csv')

plot_power_load(df_14)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from power_loads import *


df_14=pandas.read_csv('data/constant_14days.csv')

stats = {
    'Mean': df[['Time_hours', 'Power_kW']].mean(),
    'Median': df[['Time_hours', 'Power_kW']].median(),
    'Standard Deviation': df[['Time_hours', 'Power_kW']].std(),
    'Min': df[['Time_hours', 'Power_kW']].min(),
    'Max': df[['Time_hours', 'Power_kW']].max(),
}
# Display the statistics table
print(tabulate(stats, headers='keys', tablefmt='pretty'))
# Out:
# +--------------------+--------------------+--------------------+------+-------------------+
# |        Mean        |       Median       | Standard Deviation | Min  |        Max        |
# +--------------------+--------------------+--------------------+------+-------------------+
# | 167.95833333333334 | 167.95833333333331 | 97.00687260876587  | 0.0  | 335.9166666666667 |
# |        50.0        |        50.0        |        0.0         | 50.0 |       50.0        |
# +--------------------+--------------------+--------------------+------+-------------------+
