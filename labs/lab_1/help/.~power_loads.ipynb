# %% [markdown]
# # Powerloads

# %%
from power_loads import *
# Example usage
days = 2  # Number of days (this will result in time values from 0 to 48)
min_power = 10  # Minimum power (kW)
max_power = 50  # Maximum power (kW)
power_distribution = 'workweek'  # Power distribution type
filename = None  # Optional: save to file
to_csv = True

# Simulate the power load data
df = simulate_power_load(days, min_power, max_power, power_distribution, to_csv)

print(df.head())

# Set up the simulation parameters
days = 14  # Number of days
min_power = 10  # Minimum power (kW)
max_power = 50  # Maximum power (kW)
power_distribution = 'workweek'  # Power distribution type
filename = 'workweek_14days.csv'  # Optional: save to file

# Simulate the power load data
df_14 = simulate_power_load(days, min_power, max_power, power_distribution, to_csv)
df_14_constant = simulate_power_load(days, min_power, max_power, 'constant', to_csv)



# display(df.head())
# Out:
# Simulated power saved to workweek_2days.csv
#    Time_hours  Power_kW
# 0    0.000000        10
# 1    0.083333        10
# 2    0.166667        10
# 3    0.250000        10
# 4    0.333333        10
# Simulated power saved to workweek_14days.csv
# Simulated power saved to constant_14days.csv

# %%
# Example usage:
# Assuming df is the DataFrame generated from the simulate_power_load function
plot_power_load(df_14, power_distribution=power_distribution)  # Plots grouped by day of the week
