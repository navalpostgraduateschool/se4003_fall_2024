# %% [markdown]
# # This is Lab 1. Learning Python, Rust, and Jupyter for the first time.
# We are working on new code formating and conducting Lab 01 for class.
#
# **Project Objectives**
# - identify usable programs
# - *demonstrate* some markdown capability
# - test functionality of different commands
#
# *Variety* and **different text options** is one practice example function we are working on.

# %%
from power_loads import *
import pandas as pd

df_14=pandas.read_csv('data/constant_14days.csv')

plot_power_load(df_14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from power_loads import *
#       2 import pandas as pd
# ----> 4 df_14=pandas.read_csv('data/constant_14days.csv')
#       6 plot_power_load(df_14)
#
# NameError: name 'pandas' is not defined

# %%
from power_loads import *
import pandas

df_14=pandas.read_csv('data/workweek_14days.csv')

plot_power_load(df_14)

# %%
import pandas as pd
 
df_14 = pd.read_csv('data/workweek_14days.csv')
df_14_statistics = df_14.describe()
print(df_14_statistics)
# Out:
#         Time_hours     Power_kW
# count  4032.000000  4032.000000
# mean    167.958333    20.714286
# std      97.006873    17.715907
# min       0.000000    10.000000
# 25%      83.979167    10.000000
# 50%     167.958333    10.000000
# 75%     251.937500    50.000000
# max     335.916667    50.000000
