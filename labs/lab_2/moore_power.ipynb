# %% [markdown]
# # This is Lab 1:  _this is italics_
#
# Here is a description of what this data analysis program is going to do.
#
# Below I am going to plot some power form the *data/* folder for **visualization**.
#
# ## This is the second

# %%
from power_loads import *
import pandas

df_duckling=pandas.read_csv('data/constant_14days.csv')

plot_power_load(df_duckling)
